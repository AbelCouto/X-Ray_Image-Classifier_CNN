# %%
import pandas as pd
import os
import shutil

# %%
df = pd.read_csv('sample_labels.csv')

# %%
df
# Out:
#            Image Index                                     Finding Labels  \
# 0     00000013_005.png  Emphysema|Infiltration|Pleural_Thickening|Pneu...
# 1     00000013_026.png                             Cardiomegaly|Emphysema
# 2     00000017_001.png                                         No Finding
# 3     00000030_001.png                                        Atelectasis
# 4     00000032_001.png                        Cardiomegaly|Edema|Effusion
# ...                ...                                                ...
# 5601  00030712_000.png                                         No Finding
# 5602  00030786_005.png                    Cardiomegaly|Effusion|Emphysema
# 5603  00030789_000.png                                       Infiltration
# 5604  00030792_000.png                                         No Finding
# 5605  00030797_000.png                                         No Finding
#
#       Follow-up #  Patient ID Patient Age Patient Gender View Position  \
# ...

# %%
No_findings = []
df = df[df["Finding Labels"] == 'No Finding'] 
for row in df['Image Index']:
    No_findings.append(row)

# %%
print(No_findings)
# Out:
# ['00000017_001.png', '00000042_002.png', '00000057_001.png', '00000061_019.png', '00000080_005.png', '00000083_000.png', '00000099_006.png', '00000121_004.png', '00000165_008.png', '00000188_001.png', '00000194_004.png', '00000206_000.png', '00000231_005.png', '00000239_003.png', '00000246_003.png', '00000246_004.png', '00000246_018.png', '00000251_000.png', '00000265_004.png', '00000269_001.png', '00000272_003.png', '00000276_000.png', '00000277_002.png', '00000278_000.png', '00000289_001.png', '00000318_004.png', '00000334_005.png', '00000359_006.png', '00000362_001.png', '00000370_003.png', '00000390_000.png', '00000415_002.png', '00000417_001.png', '00000422_003.png', '00000422_005.png', '00000439_000.png', '00000443_000.png', '00000444_001.png', '00000450_001.png', '00000459_004.png', '00000468_015.png', '00000468_045.png', '00000473_000.png', '00000479_000.png', '00000521_000.png', '00000531_001.png', '00000531_003.png', '00000531_005.png', '00000549_002.png', '00000549_003.png
# ...

# %%
def scan_folder(parent):
    # iterate over all the files in directory 'parent'
    for file_name in os.listdir(parent):
        
        if len([item for item in No_findings if item == file_name ]) > 0:
            shutil.move(parent + file_name, dst_path )
            
F_path = '/Users/abelcouto/Documents/Dissertation/sample/Findings/'  
dst_path = '/Users/abelcouto/Documents/Dissertation/sample/No_Findings' 

scan_folder(F_path)
